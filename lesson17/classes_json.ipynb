# %% [markdown]
# # Analyzing a JSON dataset in pandas
# In this notebook we look into analyzing the PA01 dataset using Pandas

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### use read_json to read it into a data frame

# %%
df = pd.read_json('data2/classes/courses20-21.json')
df
# Out:
#       limit                                              times  enrolled  \
# 0       NaN                                                 []         0
# 1       NaN                                                 []         0
# 2       NaN                                                 []         0
# 3       NaN                                                 []         0
# 4       NaN                                                 []         0
# ...     ...                                                ...       ...
# 7808    NaN  [{'start': 840, 'days': ['tu', 'th'], 'end': 9...         5
# 7809   15.0                                                 []         4
# 7810    NaN                                                 []         3
# 7811   10.0                                                 []         6
# 7812    NaN                                                 []         1
#
#                                                 details     type  \
# 0     Instructor's Signature Required.\nSee Course C...  section
# 1     Instructor's Signature Required.\nSee Course C...  section
# 2     Instructor's Signature Required.\nSee Course C...  section
# 3     Instructor's Signature Required.\nSee Course C...  section
# 4     Instructor's Signature Required.\nSee Course C...  section
# ...                                                 ...      ...
# 7808                                                     section
# 7809                                                     section
# 7810                                                     section
# 7811                                                     section
# 7812                                                     section
#
#             status_text section  waiting  \
# 0     Open Consent Req.       2        0
# 1     Open Consent Req.       2        0
# 2     Open Consent Req.       2        0
# 3     Open Consent Req.       2        0
# 4     Open Consent Req.       2        0
# ...                 ...     ...      ...
# 7808               Open       1        0
# 7809               Open       1        0
# 7810               Open       1        0
# 7811               Open       2        0
# 7812  Open Consent Req.       1        0
#
#                                              instructor  \
# 0         [Sharon, Feiman-Nemser, snemser@brandeis.edu]
# 1               [Joseph B, Reimer, reimer@brandeis.edu]
# 2                   [Mark, Rosen, mirosen@brandeis.edu]
# 3                 [Jonathan, Sarna, sarna@brandeis.edu]
# 4                  [Ellen, Smith, esmith2@brandeis.edu]
# ...                                                 ...
# 7808              [Peter, Lupu, peterlupu@brandeis.edu]
# 7809           [Selene, Campion, scampion@brandeis.edu]
# 7810         [Nataliia, Laas, natalialaas@brandeis.edu]
# 7811  [Melissa, Kosinski-Collins, kosinski@brandeis....
# 7812             [William, Flesch, flesch@brandeis.edu]
#
#                                  coinstructors          code subject  \
# 0                                           []  [HRNS, 329F]    HRNS
# 1                                           []  [HRNS, 333F]    HRNS
# 2                                           []  [HRNS, 335F]    HRNS
# 3                                           []  [HRNS, 339F]    HRNS
# 4                                           []  [HRNS, 341F]    HRNS
# ...                                        ...           ...     ...
# 7808                                        []    [PHIL, 1A]    PHIL
# 7809                                        []   [IGS, 130A]     IGS
# 7810                                        []  [HIST, 118A]    HIST
# 7811  [[Sumana, Setty, sumana45@brandeis.edu]]   [BISC, 10B]    BISC
# 7812                                        []    [ENG, 98A]     ENG
#
#      coursenum                                        name  independent_study  \
# 0         329F  Readings in Jewish Professional Leadership               True
# 1         333F  Readings in Jewish Professional Leadership               True
# 2         335F  Readings in Jewish Professional Leadership               True
# 3         339F  Readings in Jewish Professional Leadership               True
# 4         341F  Readings in Jewish Professional Leadership               True
# ...        ...                                         ...                ...
# 7808        1A                  Introduction to Philosophy              False
# 7809      130A                            Global Migration              False
# 7810      118A         The History of American Advertising              False
# 7811       10B               The Biology of Women's Health              False
# 7812       98A                           Independent Study               True
#
#       term                                        description
# 0     1203  Meets for one-half semester and yields half-co...
# 1     1203  Meets for one-half semester and yields half-co...
# 2     1203  Meets for one-half semester and yields half-co...
# 3     1203  Meets for one-half semester and yields half-co...
# 4     1203  Meets for one-half semester and yields half-co...
# ...    ...                                                ...
# 7808  1212  Enrollment varies according to instructor. Ref...
# 7809  1212  Investigates the social, cultural, religious, ...
# 7810  1212  Considers American advertising from the eighte...
# 7811  1212  Does not meet the requirements for the major i...
# 7812  1212                 Usually offered every year.\nStaff
#
# [7813 rows x 17 columns]

# %% [markdown]
# ### look at the columms and their types
# Note that some of the types are object, e.g. times is a list of dictionaries, but stored as an object type

# %%
df.dtypes
# Out:
# limit                float64
# times                 object
# enrolled               int64
# details               object
# type                  object
# status_text           object
# section               object
# waiting                int64
# instructor            object
# coinstructors         object
# code                  object
# subject               object
# coursenum             object
# name                  object
# independent_study       bool
# term                   int64
# description           object
# dtype: object

# %% [markdown]
# ### look at all values in some column
# In pure python we used a set comprehension to get the set of subjects, here we can use the .unique() method

# %%
df['subject'].unique()

# %% [markdown]
# ### select the courses in one department

# %%
df[ df['subject']=='JAPN']

# %%
df

# %%
pt =  df.groupby('subject')['enrolled'].agg([np.sum])
pt.sort_values('sum',ascending=False).head(10)

# %%
df['email']=df['instructor'].apply(lambda x: x[2])

# %%
pt2 =  df[df['subject']=='COSI'].groupby('email')['enrolled'].agg([np.sum])
pt2.sort_values('sum',ascending=False).head(20)
